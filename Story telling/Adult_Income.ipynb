# %% [markdown]
# # ADULT INCOME DATASET
# # STORY TELLING

# %% [markdown]
# <font color = 'teal'> Importing libraries <font />

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('adult.csv')

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 4              30  United-States  <=50K

# %%
df.isna().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
df.shape
# Out:
# (48842, 15)

# %%
from numpy import nan
df=df.replace("?",nan)

# %%
df =df.dropna()

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 5   34    Private  198693          10th                6       Never-married
#
#           occupation   relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct      Own-child  Black   Male             0             0
# 1    Farming-fishing        Husband  White   Male             0             0
# 2    Protective-serv        Husband  White   Male             0             0
# 3  Machine-op-inspct        Husband  Black   Male          7688             0
# 5      Other-service  Not-in-family  White   Male             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 5              30  United-States  <=50K

# %%
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   34    Private  198693          10th                6       Never-married
#
#           occupation   relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct      Own-child  Black   Male             0             0
# 1    Farming-fishing        Husband  White   Male             0             0
# 2    Protective-serv        Husband  White   Male             0             0
# 3  Machine-op-inspct        Husband  Black   Male          7688             0
# 4      Other-service  Not-in-family  White   Male             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 4              30  United-States  <=50K

# %%
df['income']=df['income'].map({'<=50K': 0, '>50K': 1})
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   34    Private  198693          10th                6       Never-married
#
#           occupation   relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct      Own-child  Black   Male             0             0
# 1    Farming-fishing        Husband  White   Male             0             0
# 2    Protective-serv        Husband  White   Male             0             0
# 3  Machine-op-inspct        Husband  Black   Male          7688             0
# 4      Other-service  Not-in-family  White   Male             0             0
#
#    hours-per-week native-country  income
# 0              40  United-States       0
# 1              50  United-States       0
# 2              40  United-States       1
# 3              40  United-States       1
# 4              30  United-States       0

# %%
df['workclass'].unique()
# Out:
# array(['Private', 'Local-gov', 'Self-emp-not-inc', 'Federal-gov',
#        'State-gov', 'Self-emp-inc', 'Without-pay'], dtype=object)

# %%
df['native-country'].unique()
# Out:
# array(['United-States', 'Peru', 'Guatemala', 'Mexico',
#        'Dominican-Republic', 'Ireland', 'Germany', 'Philippines',
#        'Thailand', 'Haiti', 'El-Salvador', 'Puerto-Rico', 'Vietnam',
#        'South', 'Columbia', 'Japan', 'India', 'Cambodia', 'Poland',
#        'Laos', 'England', 'Cuba', 'Taiwan', 'Italy', 'Canada', 'Portugal',
#        'China', 'Nicaragua', 'Honduras', 'Iran', 'Scotland', 'Jamaica',
#        'Ecuador', 'Yugoslavia', 'Hungary', 'Hong', 'Greece',
#        'Trinadad&Tobago', 'Outlying-US(Guam-USVI-etc)', 'France',
#        'Holand-Netherlands'], dtype=object)

# %%
df['education'].unique()
# Out:
# array(['11th', 'HS-grad', 'Assoc-acdm', 'Some-college', '10th',
#        'Prof-school', '7th-8th', 'Bachelors', 'Masters', '5th-6th',
#        'Assoc-voc', '9th', 'Doctorate', '12th', '1st-4th', 'Preschool'],
#       dtype=object)

# %%
df['marital-status'].unique()
# Out:
# array(['Never-married', 'Married-civ-spouse', 'Widowed', 'Separated',
#        'Divorced', 'Married-spouse-absent', 'Married-AF-spouse'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df['occupation'].unique()
# Out:
# array(['Machine-op-inspct', 'Farming-fishing', 'Protective-serv',
#        'Other-service', 'Prof-specialty', 'Craft-repair', 'Adm-clerical',
#        'Exec-managerial', 'Tech-support', 'Sales', 'Priv-house-serv',
#        'Transport-moving', 'Handlers-cleaners', 'Armed-Forces'],
#       dtype=object)

# %% [markdown]
# # Univariate Relationship

# %%
box=df.hist(bins=25,figsize =(30,20))
plt.show()

# %%
df.groupby('native-country').count().plot(kind='bar',figsize =(16,16))

# %% [markdown]
# # Income in different countries

# %%
plt.figure(figsize=(10,10))
sns.countplot(y="native-country", hue="income",data=df[(df['native-country']=='United-States') |(df['native-country']=='Peru') | (df['native-country']=='Guatemala') | (df['native-country']== 'Mexico')| (df['native-country']=='Dominican-Republic') | (df['native-country']== 'Ireland') | (df['native-country']== 'Germany') | (df['native-country']== 'Philippines') | (df['native-country']=='Thailand') | (df['native-country']=='Haiti') | (df['native-country']== 'El-Salvador') | (df['native-country']== 'Puerto-Rico') | (df['native-country']=='Vietnam') |(df['native-country']=='South')],palette="pastel")

# %%
plt.figure(figsize=(10,10))
sns.countplot(y="native-country", hue="income",data=df[(df['native-country']=='Columbia') | (df['native-country']== 'Japan')| (df['native-country']=='India') | (df['native-country']== 'Cambodia') | (df['native-country']== 'Poland') | (df['native-country']== 'Laos') | (df['native-country']=='England') | (df['native-country']=='Cuba') | (df['native-country']== 'Taiwan') | (df['native-country']== 'Italy') | (df['native-country']=='Canada') |(df['native-country']=='Portugal')  | (df['native-country']=='China') | (df['native-country']== 'Nicaragua')],palette="pastel")

# %%
plt.figure(figsize=(10,10))
sns.countplot(y="native-country", hue="income",data=df[(df['native-country']=='Honduras') | (df['native-country']== 'Iran')| (df['native-country']=='Scotland') | (df['native-country']== 'Jamaica') | (df['native-country']== 'Ecuador') | (df['native-country']== 'Yugoslavia') | (df['native-country']=='Hungary') | (df['native-country']=='Hong') | (df['native-country']== 'Greece') | (df['native-country']== 'Trinadad&Tobago') | (df['native-country']=='Outlying-US(Guam-USVI-etc)') |(df['native-country']=='France')  | (df['native-country']=='Holand-Netherlands')],palette="pastel")

# %% [markdown]
# # Workclass VS Income

# %%
fig = plt.figure(figsize=(8,8)) 
ax = sns.countplot(x="workclass", hue="income", data=df,palette="Set3").set_title("workclass vs count")

# %% [markdown]
# # Education VS Income

# %%
fig = plt.figure(figsize=(10,10)) 
ax = sns.countplot(y="education", hue="income", data=df,palette="deep").set_title("Education vs count")

# %% [markdown]
# # Occupation VS Income

# %%
fig = plt.figure(figsize=(8,8)) 
ax = sns.countplot(y="occupation", hue="income", data=df,palette="OrRd").set_title("Occupation vs count")

# %% [markdown]
# # Gender VS Income

# %%
fig = plt.figure(figsize=(20,20)) 
ax = sns.catplot(y="marital-status", hue="gender", col="income",data=df,palette="husl", kind="count",height=4, aspect=.7);

# %%
fig = plt.figure(figsize=(20,20)) 
ax = sns.catplot(y="workclass", hue="gender", col="income",palette="deep",data=df, kind="count",height=4, aspect=.7)

# %% [markdown]
# # Race Vs Income

# %%
fig = plt.figure(figsize=(20,20)) 
ax = sns.catplot(y="race", hue="gender", col="income",palette="Set3",data=df, kind="count",height=4, aspect=.7);

# %% [markdown]
# # Relationship VS Income

# %%
fig = plt.figure(figsize=(20,20)) 
ax = sns.catplot(y="relationship", hue="gender", col="income",palette="PiYG",data=df, kind="count",height=4, aspect=.7);

# %% [markdown]
# # Age VS Income

# %%
fig = plt.figure(figsize=(20,20)) 
ax = sns.countplot(y="age", hue="income", data=df,palette="husl").set_title("Age vs count")

# %% [markdown]
# # Marital Status

# %%
fig = plt.figure(figsize=(20,20)) 
ax = sns.catplot(y="marital-status", hue="gender", col="income",palette="BuGn",data=df, kind="count",height=4, aspect=.7)

# %% [markdown]
# # Working Hours VS Income

# %%
fig = plt.figure(figsize=(20,20)) 
ax = sns.countplot(y="hours-per-week", hue="income", data=df[(df['hours-per-week'] >30 )&(df['hours-per-week'] <50)  ],palette='PuBu').set_title("Age vs count")
